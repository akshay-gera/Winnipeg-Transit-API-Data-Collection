# %%
import pandas as pd
import requests
import math
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import nan
from pandas.io.json import json_normalize

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AKSHAY~1\AppData\Local\Temp/ipykernel_10296/3266718400.py in <module>
#       1 # For 5085 bus stops we would need 5085/100 number of chunks
# ----> 2 chunks_required = round(number_of_stops/100)
#       3
#       4 # Creating a function which will take stops list and chunks required as input
#       5 # The function with create sub-lists of 100 elements in the whole stops list of 5085 stops
#
# NameError: name 'number_of_stops' is not defined

# %%
response = requests.get("https://api.winnipegtransit.com/v3/statuses.json?api-key=wPOIZFdePaV6BdttKD7C")
a = response.json()['statuses']
df_status = json_normalize(a)
df_status
# Out:
# C:\Users\AKSHAY~1\AppData\Local\Temp/ipykernel_25096/2242033022.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_status = json_normalize(a)
#        name    value                                      description  \
# 0   omnibus   normal  The current status of the Omnibus Web Services.
# 1  schedule  regular                                              NaN
#
#             updated-at                                            message
# 0  2022-12-26T09:41:10                                                NaN
# 1                  NaN  Winnipeg Transit is currently operating regula...

# %%
df_status.message[1]
# Out:
# 'Winnipeg Transit is currently operating regular service'

# %%
df_stops = pd.read_csv('Bus_Stops.csv')
df_stops.number= df_stops.number.astype('Int64').astype('str')
stop_numbers_list = list(set(df_stops['number']))
number_of_stops = len(stop_numbers_list)
number_of_stops
# Out:
# 5085

# %%
# For 5085 bus stops we would need 5087/100 number of chunks
chunks_required = round(number_of_stops/100)

# Creating a function which will take stops list and chunks required as input
# The function with create sub-lists of 100 elements in the whole stops list of 5085 stops

def divide_chunks(stop_numbers_list,chunks_required):
    
    # Loops starts with 0 till number of stops and hops on to every another 100th element of the list
    
    for i in range(0, number_of_stops, 100):
        
        # Indexes from 100 till another 100th element
        # For example indexing at first loop i=0 is [0:100]
        # For second loop the i=100 and indexing is [100:200]
        yield stop_numbers_list[i:i + 100]

# %%
# Calling the function and giving it object name bus_stop_chunks
# Bus_stop_chunks in coverted list of chunks of list with 100 elements each

bus_stops_chunks = list(divide_chunks(stop_numbers_list, chunks_required))
print(f'Number of bus_stops chunks from original bus stops list: {len(bus_stops_chunks)}')
print(f'Number of elements in each chunk: {len(bus_stops_chunks[0])}')
# Out:
# Number of bus_stops chunks from original bus stops list: 51
# Number of elements in each chunk: 100

# %%
# Creating a function which will go inside in each bus_stop chunk list elements
# And make an api call for each bus stop

# This dataframe will capture schedule for each bus variant
df_each_stop_schedule_per_bus = pd.DataFrame()

# This data frame will populate with all bus variants schedule for each stop
df_each_stop_schedule = pd.DataFrame()

# Initializing with an empty pandas dataframe which will populate with with a chunk of 100 stops
df_stop_schedule_per_chunk = pd.DataFrame()



# This function takes in chunk_index(what chunk of the whole list to work on)
# Then for each chunk makes api calls of bus stops in that chunk

def bus_stop_schedule_chunkwise(chunk_index):
    
    # Declaring the initialized dataframe variable df_stop_schedule as a global variable
    # Without it the function will consider it to be local variable and not work
    global df_stop_schedule_per_chunk
    global df_each_stop_schedule
    global df_each_stop_schedule_per_bus
    
    # Running a for loop to make api call for each stop in the bus_stops_chunks list
    for stop in bus_stops_chunks[chunk_index]:
        if stop != None:
            try:
                response = requests.get(f"https://api.winnipegtransit.com/v3/stops/{stop}/schedule.json?api-key=wPOIZFdePaV6BdttKD7C")
                json_format = response.json()['stop-schedule']

             # Recording the information got into a temporary frame df_each_stop_schedule
                #df_each_stop_schedule = pd.DataFrame()
                #df_each_stop_schedule['name'] = 'Nothing'
                #df_each_stop_schedule['count'] = None
                #df_each_stop_schedule['Stop_Number'] = stop
                #df_each_stop_schedule.loc[len(df_each_stop_schedule.index)] = [None,None, f'{stop}']
                
                # If the search returns no errors or any empty value
                if json_format['route-schedules'] == []:
                    df_each_stop_schedule['Stop_Number'] = stop
                   
                    #print(f'Empty row added for variant {stop}')
                    
                # If the api search returns a blank search, the stop will be recorded in the dataframe with empty values
                else:
                    for i in range(len(json_format['route-schedules'])):
                        df_each_stop_schedule_per_bus = pd.json_normalize(json_format['route-schedules'][i]['scheduled-stops'])
                        df_each_stop_schedule_per_bus['Stop_Number'] = stop
                        df_each_stop_schedule = pd.concat([df_each_stop_schedule,df_each_stop_schedule_per_bus], ignore_index=True)
                    

            except:
                print(f'{stop} returned error in search. No values found for this variant')

            # Simulatenous concatanetion of each stop's info in df_stop_feature_chunk
            # This dataframe will contain records for each chunk of the big 5085 stops list
            df_stop_schedule_per_chunk = pd.concat([df_stop_schedule_per_chunk,df_each_stop_schedule], ignore_index=True)

# %%
chunk_index=0

# %%
bus_stop_schedule_chunkwise(chunk_index=0)

# %%
df_stop_schedule_per_chunk
# Out:
#       Stop_Number          key cancelled times.departure.scheduled  \
# 0           40644   22722791-1     false       2022-12-26T11:48:00
# 1           40644   22722776-1     false       2022-12-26T12:36:00
# 2           30861   22722791-1     false       2022-12-26T11:48:00
# 3           30861   22722776-1     false       2022-12-26T12:36:00
# 4           30861   22722791-1     false       2022-12-26T11:48:00
# ...           ...          ...       ...                       ...
# 15217       10759  22721873-19     false       2022-12-26T12:25:42
# 15218       10759  22722333-29     false       2022-12-26T11:21:35
# 15219       10759  22722334-29     false       2022-12-26T11:49:35
# 15220       10759  22722335-29     false       2022-12-26T12:18:35
# 15221       10759  22722336-29     false       2022-12-26T12:47:17
#
#       times.departure.estimated variant.key  \
# 0           2022-12-26T11:48:00      11-0-C
# 1           2022-12-26T12:36:00      11-0-C
# 2           2022-12-26T11:48:00      11-0-C
# 3           2022-12-26T12:36:00      11-0-C
# 4           2022-12-26T11:48:00      11-0-C
# ...                         ...         ...
# 15217       2022-12-26T12:25:42      38-0-T
# 15218       2022-12-26T11:21:35      17-0-A
# 15219       2022-12-26T11:49:35      17-0-M
# 15220       2022-12-26T12:18:35      17-0-A
# 15221       2022-12-26T12:47:17      17-0-M
#
#                             variant.name  bus.key bus.bike-rack bus.wifi  \
# 0      Portage-Kildonan to Crestview via    191.0         false    false
# 1      Portage-Kildonan to Crestview via    192.0         false    false
# 2      Portage-Kildonan to Crestview via    191.0         false    false
# 3      Portage-Kildonan to Crestview via    192.0         false    false
# 4      Portage-Kildonan to Crestview via    191.0         false    false
# ...                                  ...      ...           ...      ...
# 15217   Salter to Templeton & McPhillips    419.0          true    false
# 15218       McGregor to Amber Trails via    858.0         false    false
# 15219             McGregor to Maples via    318.0         false    false
# 15220       McGregor to Amber Trails via    198.0         false    false
# 15221             McGregor to Maples via    433.0          true    false
#
#       times.arrival.scheduled times.arrival.estimated
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ...                       ...                     ...
# 15217     2022-12-26T12:25:42     2022-12-26T12:25:42
# 15218     2022-12-26T11:21:35     2022-12-26T11:21:35
# 15219     2022-12-26T11:49:35     2022-12-26T11:49:35
# 15220     2022-12-26T12:18:35     2022-12-26T12:18:35
# 15221     2022-12-26T12:47:17     2022-12-26T12:47:17
#
# [15222 rows x 12 columns]

# %%
stop = '10543'
response = requests.get(f"https://api.winnipegtransit.com/v3/stops/{stop}/schedule.json?api-key=wPOIZFdePaV6BdttKD7C")
json_format = response.json()['stop-schedule']

# %%
json_format
if json_format == []:
    df_each_stop_schedule['Stop_Number'] = stop

    #print(f'Empty row added for variant {stop}')

# If the api search returns a blank search, the stop will be recorded in the dataframe with empty values
else:
    df_each_stop_schedule = pd.json_normalize(json_format['route-schedules'][0]['scheduled-stops'])
    df_each_stop_schedule['Stop_Number'] = stop

# %%
json_format
# Out:
# {'stop': {'key': 10543,
#   'name': 'Westbound Portage at Edmonton (Portage Place)',
#   'number': 10543,
#   'direction': 'Westbound',
#   'side': 'Nearside Opposite',
#   'street': {'key': 2903, 'name': 'Portage Avenue', 'type': 'Avenue'},
#   'cross-street': {'key': 1201, 'name': 'Edmonton Street', 'type': 'Street'},
#   'centre': {'utm': {'zone': '14U', 'x': 633089, 'y': 5528322},
#    'geographic': {'latitude': '49.89248', 'longitude': '-97.14703'}}},
#  'route-schedules': [{'route': {'key': 55,
#     'number': 55,
#     'name': "Route 55 St. Anne's",
#     'customer-type': 'regular',
#     'coverage': 'regular',
#     'badge-label': 55,
#     'badge-style': {'class-names': {'class-name': ['badge-label', 'regular']},
#      'background-color': '#ffffff',
#      'border-color': '#d9d9d9',
#      'color': '#000000'}},
#    'scheduled-stops': [{'key': '22721627-49',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:35:01',
#        'estimated': '2022-12-26T10:38:39'},
#       'departure': {'scheduled': '2022-12-26T10:35:01',
#        'estimated': '2022-12-26T10:38:39'}},
#      'variant': {'key': '55-1-D',
#       'name': "St.Anne's to University of Winnipeg via Dakota"},
#      'bus': {'key': 861, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22721628-59',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:04:01',
#        'estimated': '2022-12-26T11:04:01'},
#       'departure': {'scheduled': '2022-12-26T11:04:01',
#        'estimated': '2022-12-26T11:04:01'}},
#      'variant': {'key': '55-1-M',
#       'name': "St.Anne's to University of Winnipeg via Meadowood"},
#      'bus': {'key': 811, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22721629-49',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:33:01',
#        'estimated': '2022-12-26T11:33:01'},
#       'departure': {'scheduled': '2022-12-26T11:33:01',
#        'estimated': '2022-12-26T11:33:01'}},
#      'variant': {'key': '55-1-D',
#       'name': "St.Anne's to University of Winnipeg via Dakota"},
#      'bus': {'key': 856, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22721630-59',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:02:01',
#        'estimated': '2022-12-26T12:02:01'},
#       'departure': {'scheduled': '2022-12-26T12:02:01',
#        'estimated': '2022-12-26T12:02:01'}},
#      'variant': {'key': '55-1-M',
#       'name': "St.Anne's to University of Winnipeg via Meadowood"},
#      'bus': {'key': 861, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22721631-49',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:32:01',
#        'estimated': '2022-12-26T12:32:01'},
#       'departure': {'scheduled': '2022-12-26T12:32:01',
#        'estimated': '2022-12-26T12:32:01'}},
#      'variant': {'key': '55-1-D',
#       'name': "St.Anne's to University of Winnipeg via Dakota"},
#      'bus': {'key': 811, 'bike-rack': 'false', 'wifi': 'false'}}]},
#   {'route': {'key': 11,
#     'number': 11,
#     'name': 'Route 11 Portage-Kildonan',
#     'customer-type': 'regular',
#     'coverage': 'regular',
#     'badge-label': 11,
#     'badge-style': {'class-names': {'class-name': ['badge-label', 'regular']},
#      'background-color': '#ffffff',
#      'border-color': '#d9d9d9',
#      'color': '#000000'}},
#    'scheduled-stops': [{'key': '22722785-47',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:42:51',
#        'estimated': '2022-12-26T10:43:24'},
#       'departure': {'scheduled': '2022-12-26T10:42:51',
#        'estimated': '2022-12-26T10:43:24'}},
#      'variant': {'key': '11-0-C', 'name': 'Portage-Kildonan to Crestview via'},
#      'bus': {'key': 192, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722786-46',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:58:51',
#        'estimated': '2022-12-26T10:58:51'},
#       'departure': {'scheduled': '2022-12-26T10:58:51',
#        'estimated': '2022-12-26T10:58:51'}},
#      'variant': {'key': '11-0-S',
#       'name': 'Portage-Kildonan to St. Charles via'},
#      'bus': {'key': 870, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722787-47',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:14:51',
#        'estimated': '2022-12-26T11:14:51'},
#       'departure': {'scheduled': '2022-12-26T11:14:51',
#        'estimated': '2022-12-26T11:14:51'}},
#      'variant': {'key': '11-0-W', 'name': 'Portage-Kildonan to Westwood via'},
#      'bus': {'key': 877, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722788-47',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:30:51',
#        'estimated': '2022-12-26T11:30:51'},
#       'departure': {'scheduled': '2022-12-26T11:30:51',
#        'estimated': '2022-12-26T11:30:51'}},
#      'variant': {'key': '11-0-C', 'name': 'Portage-Kildonan to Crestview via'},
#      'bus': {'key': 635, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722859-6',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:38:51',
#        'estimated': '2022-12-26T11:38:51'},
#       'departure': {'scheduled': '2022-12-26T11:38:51',
#        'estimated': '2022-12-26T11:38:51'}},
#      'variant': {'key': '11-0-P', 'name': 'Portage-Kildonan to Polo Park'},
#      'bus': {'key': 784, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722789-46',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:46:51',
#        'estimated': '2022-12-26T11:46:51'},
#       'departure': {'scheduled': '2022-12-26T11:46:51',
#        'estimated': '2022-12-26T11:46:51'}},
#      'variant': {'key': '11-0-S',
#       'name': 'Portage-Kildonan to St. Charles via'},
#      'bus': {'key': 163, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722875-6',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:53:51',
#        'estimated': '2022-12-26T11:53:51'},
#       'departure': {'scheduled': '2022-12-26T11:53:51',
#        'estimated': '2022-12-26T11:53:51'}},
#      'variant': {'key': '11-0-P', 'name': 'Portage-Kildonan to Polo Park'},
#      'bus': {'key': 834, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722790-47',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:01:51',
#        'estimated': '2022-12-26T12:01:51'},
#       'departure': {'scheduled': '2022-12-26T12:01:51',
#        'estimated': '2022-12-26T12:01:51'}},
#      'variant': {'key': '11-0-W', 'name': 'Portage-Kildonan to Westwood via'},
#      'bus': {'key': 320, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722842-6',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:09:51',
#        'estimated': '2022-12-26T12:09:51'},
#       'departure': {'scheduled': '2022-12-26T12:09:51',
#        'estimated': '2022-12-26T12:09:51'}},
#      'variant': {'key': '11-0-P', 'name': 'Portage-Kildonan to Polo Park'},
#      'bus': {'key': 728, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722791-47',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:17:51',
#        'estimated': '2022-12-26T12:17:51'},
#       'departure': {'scheduled': '2022-12-26T12:17:51',
#        'estimated': '2022-12-26T12:17:51'}},
#      'variant': {'key': '11-0-C', 'name': 'Portage-Kildonan to Crestview via'},
#      'bus': {'key': 191, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722857-6',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:25:51',
#        'estimated': '2022-12-26T12:25:51'},
#       'departure': {'scheduled': '2022-12-26T12:25:51',
#        'estimated': '2022-12-26T12:25:51'}},
#      'variant': {'key': '11-0-P', 'name': 'Portage-Kildonan to Polo Park'},
#      'bus': {'key': 784, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722774-46',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:33:51',
#        'estimated': '2022-12-26T12:33:51'},
#       'departure': {'scheduled': '2022-12-26T12:33:51',
#        'estimated': '2022-12-26T12:33:51'}},
#      'variant': {'key': '11-0-S',
#       'name': 'Portage-Kildonan to St. Charles via'},
#      'bus': {'key': 300, 'bike-rack': 'false', 'wifi': 'false'}}]},
#   {'route': {'key': 14,
#     'number': 14,
#     'name': "Route 14 Ellice-St. Mary's",
#     'customer-type': 'regular',
#     'coverage': 'regular',
#     'badge-label': 14,
#     'badge-style': {'class-names': {'class-name': ['badge-label', 'regular']},
#      'background-color': '#ffffff',
#      'border-color': '#d9d9d9',
#      'color': '#000000'}},
#    'scheduled-stops': [{'key': '22722591-64',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:42:16',
#        'estimated': '2022-12-26T10:41:38'},
#       'departure': {'scheduled': '2022-12-26T10:42:16',
#        'estimated': '2022-12-26T10:41:38'}},
#      'variant': {'key': '14-1-E', 'name': "St. Mary's-Ellice to Ferry Road"},
#      'bus': {'key': 194, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722600-64',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:10:16',
#        'estimated': '2022-12-26T11:10:16'},
#       'departure': {'scheduled': '2022-12-26T11:10:16',
#        'estimated': '2022-12-26T11:10:16'}},
#      'variant': {'key': '14-1-E', 'name': "St. Mary's-Ellice to Ferry Road"},
#      'bus': {'key': 863, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722592-64',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:39:16',
#        'estimated': '2022-12-26T11:39:16'},
#       'departure': {'scheduled': '2022-12-26T11:39:16',
#        'estimated': '2022-12-26T11:39:16'}},
#      'variant': {'key': '14-1-E', 'name': "St. Mary's-Ellice to Ferry Road"},
#      'bus': {'key': 366, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722601-64',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:08:35',
#        'estimated': '2022-12-26T12:08:35'},
#       'departure': {'scheduled': '2022-12-26T12:08:35',
#        'estimated': '2022-12-26T12:08:35'}},
#      'variant': {'key': '14-1-E', 'name': "St. Mary's-Ellice to Ferry Road"},
#      'bus': {'key': 702, 'bike-rack': 'false', 'wifi': 'false'}}]},
#   {'route': {'key': 15,
#     'number': 15,
#     'name': 'Route 15 Sargent-Mountain',
#     'customer-type': 'regular',
#     'coverage': 'regular',
#     'badge-label': 15,
#     'badge-style': {'class-names': {'class-name': ['badge-label', 'regular']},
#      'background-color': '#ffffff',
#      'border-color': '#d9d9d9',
#      'color': '#000000'}},
#    'scheduled-stops': [{'key': '22722493-31',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:41:06',
#        'estimated': '2022-12-26T10:42:10'},
#       'departure': {'scheduled': '2022-12-26T10:41:06',
#        'estimated': '2022-12-26T10:42:10'}},
#      'variant': {'key': '15-0-W',
#       'name': 'Sargent-Mountain to Airport via Wellington'},
#      'bus': {'key': 161, 'bike-rack': 'true', 'wifi': 'false'}},
#     {'key': '22722494-31',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:04:06',
#        'estimated': '2022-12-26T11:04:06'},
#       'departure': {'scheduled': '2022-12-26T11:04:06',
#        'estimated': '2022-12-26T11:04:06'}},
#      'variant': {'key': '15-0-W',
#       'name': 'Sargent-Mountain to Airport via Wellington'},
#      'bus': {'key': 302, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722495-31',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:27:06',
#        'estimated': '2022-12-26T11:27:06'},
#       'departure': {'scheduled': '2022-12-26T11:27:06',
#        'estimated': '2022-12-26T11:27:06'}},
#      'variant': {'key': '15-0-W',
#       'name': 'Sargent-Mountain to Airport via Wellington'},
#      'bus': {'key': 871, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722496-31',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:51:06',
#        'estimated': '2022-12-26T11:51:06'},
#       'departure': {'scheduled': '2022-12-26T11:51:06',
#        'estimated': '2022-12-26T11:51:06'}},
#      'variant': {'key': '15-0-W',
#       'name': 'Sargent-Mountain to Airport via Wellington'},
#      'bus': {'key': 743, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722497-31',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:15:22',
#        'estimated': '2022-12-26T12:15:22'},
#       'departure': {'scheduled': '2022-12-26T12:15:22',
#        'estimated': '2022-12-26T12:15:22'}},
#      'variant': {'key': '15-0-W',
#       'name': 'Sargent-Mountain to Airport via Wellington'},
#      'bus': {'key': 161, 'bike-rack': 'true', 'wifi': 'false'}}]},
#   {'route': {'key': 38,
#     'number': 38,
#     'name': 'Route 38 Salter',
#     'customer-type': 'regular',
#     'coverage': 'regular',
#     'badge-label': 38,
#     'badge-style': {'class-names': {'class-name': ['badge-label', 'regular']},
#      'background-color': '#ffffff',
#      'border-color': '#d9d9d9',
#      'color': '#000000'}},
#    'scheduled-stops': [{'key': '22721871-9',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:48:57',
#        'estimated': '2022-12-26T10:48:57'},
#       'departure': {'scheduled': '2022-12-26T10:48:57',
#        'estimated': '2022-12-26T10:48:57'}},
#      'variant': {'key': '38-0-T', 'name': 'Salter to Templeton & McPhillips'},
#      'bus': {'key': 419, 'bike-rack': 'true', 'wifi': 'false'}},
#     {'key': '22721872-9',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:32:57',
#        'estimated': '2022-12-26T11:32:57'},
#       'departure': {'scheduled': '2022-12-26T11:32:57',
#        'estimated': '2022-12-26T11:32:57'}},
#      'variant': {'key': '38-0-T', 'name': 'Salter to Templeton & McPhillips'},
#      'bus': {'key': 879, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22721873-9',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:18:36',
#        'estimated': '2022-12-26T12:18:36'},
#       'departure': {'scheduled': '2022-12-26T12:18:36',
#        'estimated': '2022-12-26T12:18:36'}},
#      'variant': {'key': '38-0-T', 'name': 'Salter to Templeton & McPhillips'},
#      'bus': {'key': 419, 'bike-rack': 'true', 'wifi': 'false'}}]},
#   {'route': {'key': 19,
#     'number': 19,
#     'name': 'Route 19 Marion-Logan-Notre Dame',
#     'customer-type': 'regular',
#     'coverage': 'regular',
#     'badge-label': 19,
#     'badge-style': {'class-names': {'class-name': ['badge-label', 'regular']},
#      'background-color': '#ffffff',
#      'border-color': '#d9d9d9',
#      'color': '#000000'}},
#    'scheduled-stops': [{'key': '22722159-38',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T10:54:15',
#        'estimated': '2022-12-26T10:54:15'},
#       'departure': {'scheduled': '2022-12-26T10:54:15',
#        'estimated': '2022-12-26T10:54:15'}},
#      'variant': {'key': '19-0-L',
#       'name': 'Marion-Logan-Notre Dame to Red River College via Logan'},
#      'bus': {'key': 779, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722160-45',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:21:15',
#        'estimated': '2022-12-26T11:21:15'},
#       'departure': {'scheduled': '2022-12-26T11:21:15',
#        'estimated': '2022-12-26T11:21:15'}},
#      'variant': {'key': '19-0-N',
#       'name': 'Marion-Logan-Notre Dame to Red River College via Notre Dame'},
#      'bus': {'key': 160, 'bike-rack': 'true', 'wifi': 'false'}},
#     {'key': '22722161-38',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T11:48:15',
#        'estimated': '2022-12-26T11:48:15'},
#       'departure': {'scheduled': '2022-12-26T11:48:15',
#        'estimated': '2022-12-26T11:48:15'}},
#      'variant': {'key': '19-0-L',
#       'name': 'Marion-Logan-Notre Dame to Red River College via Logan'},
#      'bus': {'key': 369, 'bike-rack': 'false', 'wifi': 'false'}},
#     {'key': '22722162-45',
#      'cancelled': 'false',
#      'times': {'arrival': {'scheduled': '2022-12-26T12:15:15',
#        'estimated': '2022-12-26T12:15:15'},
#       'departure': {'scheduled': '2022-12-26T12:15:15',
#        'estimated': '2022-12-26T12:15:15'}},
#      'variant': {'key': '19-0-N',
#       'name': 'Marion-Logan-Notre Dame to Red River College via Notre Dame'},
#      'bus': {'key': 823, 'bike-rack': 'false', 'wifi': 'false'}}]}]}

# %%
for i in range(len(json_format['route-schedules'])):
    if json_format['route-schedules'][i] == []:
        df_each_stop_schedule['Stop_Number'][i] = stop

    #print(f'Empty row added for variant {stop}')

    # If the api search returns a blank search, the stop will be recorded in the dataframe with empty values
    else:
        df_each_stop_schedule = pd.json_normalize(json_format['route-schedules'][i]['scheduled-stops'])
        df_each_stop_schedule['Stop_Number'] = stop

# %%
df_each_stop_schedule
# Out:
#            key cancelled times.arrival.scheduled times.arrival.estimated  \
# 0  22722159-38     false     2022-12-26T10:54:15     2022-12-26T10:54:15
# 1  22722160-45     false     2022-12-26T11:21:15     2022-12-26T11:21:15
# 2  22722161-38     false     2022-12-26T11:48:15     2022-12-26T11:48:15
# 3  22722162-45     false     2022-12-26T12:15:15     2022-12-26T12:15:15
#
#   times.departure.scheduled times.departure.estimated variant.key  \
# 0       2022-12-26T10:54:15       2022-12-26T10:54:15      19-0-L
# 1       2022-12-26T11:21:15       2022-12-26T11:21:15      19-0-N
# 2       2022-12-26T11:48:15       2022-12-26T11:48:15      19-0-L
# 3       2022-12-26T12:15:15       2022-12-26T12:15:15      19-0-N
#
#                                         variant.name  bus.key bus.bike-rack  \
# 0  Marion-Logan-Notre Dame to Red River College v...      779         false
# 1  Marion-Logan-Notre Dame to Red River College v...      160          true
# 2  Marion-Logan-Notre Dame to Red River College v...      369         false
# 3  Marion-Logan-Notre Dame to Red River College v...      823         false
#
#   bus.wifi Stop_Number
# 0    false       10543
# 1    false       10543
# 2    false       10543
# 3    false       10543

# %%
df_each_stop_schedule_per_bus = pd.DataFrame()
for i in range(len(json_format['route-schedules'])):
    df_each_stop_schedule_per_bus = pd.json_normalize(json_format['route-schedules'][i]['scheduled-stops'])
    df_each_stop_schedule_per_bus['Stop_Number'] = stop
    df_each_stop_schedule = pd.concat([df_each_stop_schedule,df_each_stop_schedule_per_bus], ignore_index=True)

# %%
df_each_stop_schedule
# Out:
#             key cancelled times.arrival.scheduled times.arrival.estimated  \
# 0   22722159-38     false     2022-12-26T10:54:15     2022-12-26T10:54:15
# 1   22722160-45     false     2022-12-26T11:21:15     2022-12-26T11:21:15
# 2   22722161-38     false     2022-12-26T11:48:15     2022-12-26T11:48:15
# 3   22722162-45     false     2022-12-26T12:15:15     2022-12-26T12:15:15
# 4   22721627-49     false     2022-12-26T10:35:01     2022-12-26T10:38:39
# 5   22721628-59     false     2022-12-26T11:04:01     2022-12-26T11:04:01
# 6   22721629-49     false     2022-12-26T11:33:01     2022-12-26T11:33:01
# 7   22721630-59     false     2022-12-26T12:02:01     2022-12-26T12:02:01
# 8   22721631-49     false     2022-12-26T12:32:01     2022-12-26T12:32:01
# 9   22722785-47     false     2022-12-26T10:42:51     2022-12-26T10:43:24
# 10  22722786-46     false     2022-12-26T10:58:51     2022-12-26T10:58:51
# 11  22722787-47     false     2022-12-26T11:14:51     2022-12-26T11:14:51
# 12  22722788-47     false     2022-12-26T11:30:51     2022-12-26T11:30:51
# 13   22722859-6     false     2022-12-26T11:38:51     2022-12-26T11:38:51
# 14  22722789-46     false     2022-12-26T11:46:51     2022-12-26T11:46:51
# 15   22722875-6     false     2022-12-26T11:53:51     2022-12-26T11:53:51
# 16  22722790-47     false     2022-12-26T12:01:51     2022-12-26T12:01:51
# 17   22722842-6     false     2022-12-26T12:09:51     2022-12-26T12:09:51
# 18  22722791-47     false     2022-12-26T12:17:51     2022-12-26T12:17:51
# 19   22722857-6     false     2022-12-26T12:25:51     2022-12-26T12:25:51
# 20  22722774-46     false     2022-12-26T12:33:51     2022-12-26T12:33:51
# 21  22722591-64     false     2022-12-26T10:42:16     2022-12-26T10:41:38
# 22  22722600-64     false     2022-12-26T11:10:16     2022-12-26T11:10:16
# 23  22722592-64     false     2022-12-26T11:39:16     2022-12-26T11:39:16
# 24  22722601-64     false     2022-12-26T12:08:35     2022-12-26T12:08:35
# 25  22722493-31     false     2022-12-26T10:41:06     2022-12-26T10:42:10
# 26  22722494-31     false     2022-12-26T11:04:06     2022-12-26T11:04:06
# 27  22722495-31     false     2022-12-26T11:27:06     2022-12-26T11:27:06
# 28  22722496-31     false     2022-12-26T11:51:06     2022-12-26T11:51:06
# 29  22722497-31     false     2022-12-26T12:15:22     2022-12-26T12:15:22
# 30   22721871-9     false     2022-12-26T10:48:57     2022-12-26T10:48:57
# 31   22721872-9     false     2022-12-26T11:32:57     2022-12-26T11:32:57
# 32   22721873-9     false     2022-12-26T12:18:36     2022-12-26T12:18:36
# 33  22722159-38     false     2022-12-26T10:54:15     2022-12-26T10:54:15
# 34  22722160-45     false     2022-12-26T11:21:15     2022-12-26T11:21:15
# 35  22722161-38     false     2022-12-26T11:48:15     2022-12-26T11:48:15
# 36  22722162-45     false     2022-12-26T12:15:15     2022-12-26T12:15:15
#
#    times.departure.scheduled times.departure.estimated variant.key  \
# 0        2022-12-26T10:54:15       2022-12-26T10:54:15      19-0-L
# 1        2022-12-26T11:21:15       2022-12-26T11:21:15      19-0-N
# 2        2022-12-26T11:48:15       2022-12-26T11:48:15      19-0-L
# 3        2022-12-26T12:15:15       2022-12-26T12:15:15      19-0-N
# 4        2022-12-26T10:35:01       2022-12-26T10:38:39      55-1-D
# 5        2022-12-26T11:04:01       2022-12-26T11:04:01      55-1-M
# 6        2022-12-26T11:33:01       2022-12-26T11:33:01      55-1-D
# 7        2022-12-26T12:02:01       2022-12-26T12:02:01      55-1-M
# 8        2022-12-26T12:32:01       2022-12-26T12:32:01      55-1-D
# 9        2022-12-26T10:42:51       2022-12-26T10:43:24      11-0-C
# 10       2022-12-26T10:58:51       2022-12-26T10:58:51      11-0-S
# 11       2022-12-26T11:14:51       2022-12-26T11:14:51      11-0-W
# 12       2022-12-26T11:30:51       2022-12-26T11:30:51      11-0-C
# 13       2022-12-26T11:38:51       2022-12-26T11:38:51      11-0-P
# 14       2022-12-26T11:46:51       2022-12-26T11:46:51      11-0-S
# 15       2022-12-26T11:53:51       2022-12-26T11:53:51      11-0-P
# 16       2022-12-26T12:01:51       2022-12-26T12:01:51      11-0-W
# 17       2022-12-26T12:09:51       2022-12-26T12:09:51      11-0-P
# 18       2022-12-26T12:17:51       2022-12-26T12:17:51      11-0-C
# 19       2022-12-26T12:25:51       2022-12-26T12:25:51      11-0-P
# 20       2022-12-26T12:33:51       2022-12-26T12:33:51      11-0-S
# 21       2022-12-26T10:42:16       2022-12-26T10:41:38      14-1-E
# 22       2022-12-26T11:10:16       2022-12-26T11:10:16      14-1-E
# 23       2022-12-26T11:39:16       2022-12-26T11:39:16      14-1-E
# 24       2022-12-26T12:08:35       2022-12-26T12:08:35      14-1-E
# 25       2022-12-26T10:41:06       2022-12-26T10:42:10      15-0-W
# 26       2022-12-26T11:04:06       2022-12-26T11:04:06      15-0-W
# 27       2022-12-26T11:27:06       2022-12-26T11:27:06      15-0-W
# 28       2022-12-26T11:51:06       2022-12-26T11:51:06      15-0-W
# 29       2022-12-26T12:15:22       2022-12-26T12:15:22      15-0-W
# 30       2022-12-26T10:48:57       2022-12-26T10:48:57      38-0-T
# 31       2022-12-26T11:32:57       2022-12-26T11:32:57      38-0-T
# 32       2022-12-26T12:18:36       2022-12-26T12:18:36      38-0-T
# 33       2022-12-26T10:54:15       2022-12-26T10:54:15      19-0-L
# 34       2022-12-26T11:21:15       2022-12-26T11:21:15      19-0-N
# 35       2022-12-26T11:48:15       2022-12-26T11:48:15      19-0-L
# 36       2022-12-26T12:15:15       2022-12-26T12:15:15      19-0-N
#
#                                          variant.name  bus.key bus.bike-rack  \
# 0   Marion-Logan-Notre Dame to Red River College v...      779         false
# 1   Marion-Logan-Notre Dame to Red River College v...      160          true
# 2   Marion-Logan-Notre Dame to Red River College v...      369         false
# 3   Marion-Logan-Notre Dame to Red River College v...      823         false
# 4      St.Anne's to University of Winnipeg via Dakota      861         false
# 5   St.Anne's to University of Winnipeg via Meadowood      811         false
# 6      St.Anne's to University of Winnipeg via Dakota      856         false
# 7   St.Anne's to University of Winnipeg via Meadowood      861         false
# 8      St.Anne's to University of Winnipeg via Dakota      811         false
# 9                   Portage-Kildonan to Crestview via      192         false
# 10                Portage-Kildonan to St. Charles via      870         false
# 11                   Portage-Kildonan to Westwood via      877         false
# 12                  Portage-Kildonan to Crestview via      635         false
# 13                      Portage-Kildonan to Polo Park      784         false
# 14                Portage-Kildonan to St. Charles via      163         false
# 15                      Portage-Kildonan to Polo Park      834         false
# 16                   Portage-Kildonan to Westwood via      320         false
# 17                      Portage-Kildonan to Polo Park      728         false
# 18                  Portage-Kildonan to Crestview via      191         false
# 19                      Portage-Kildonan to Polo Park      784         false
# 20                Portage-Kildonan to St. Charles via      300         false
# 21                    St. Mary's-Ellice to Ferry Road      194         false
# 22                    St. Mary's-Ellice to Ferry Road      863         false
# 23                    St. Mary's-Ellice to Ferry Road      366         false
# 24                    St. Mary's-Ellice to Ferry Road      702         false
# 25         Sargent-Mountain to Airport via Wellington      161          true
# 26         Sargent-Mountain to Airport via Wellington      302         false
# 27         Sargent-Mountain to Airport via Wellington      871         false
# 28         Sargent-Mountain to Airport via Wellington      743         false
# 29         Sargent-Mountain to Airport via Wellington      161          true
# 30                   Salter to Templeton & McPhillips      419          true
# 31                   Salter to Templeton & McPhillips      879         false
# 32                   Salter to Templeton & McPhillips      419          true
# 33  Marion-Logan-Notre Dame to Red River College v...      779         false
# 34  Marion-Logan-Notre Dame to Red River College v...      160          true
# 35  Marion-Logan-Notre Dame to Red River College v...      369         false
# 36  Marion-Logan-Notre Dame to Red River College v...      823         false
#
#    bus.wifi Stop_Number
# 0     false       10543
# 1     false       10543
# 2     false       10543
# 3     false       10543
# 4     false       10543
# 5     false       10543
# 6     false       10543
# 7     false       10543
# 8     false       10543
# 9     false       10543
# 10    false       10543
# 11    false       10543
# 12    false       10543
# 13    false       10543
# 14    false       10543
# 15    false       10543
# 16    false       10543
# 17    false       10543
# 18    false       10543
# 19    false       10543
# 20    false       10543
# 21    false       10543
# 22    false       10543
# 23    false       10543
# 24    false       10543
# 25    false       10543
# 26    false       10543
# 27    false       10543
# 28    false       10543
# 29    false       10543
# 30    false       10543
# 31    false       10543
# 32    false       10543
# 33    false       10543
# 34    false       10543
# 35    false       10543
# 36    false       10543

# %%
if json_format == []:
    df_each_stop_schedule['Stop_Number'] = stop

    #print(f'Empty row added for variant {stop}')

# If the api search returns a blank search, the stop will be recorded in the dataframe with empty values
else:
    df_each_stop_schedule = pd.json_normalize(json_format['route-schedules'][0]['scheduled-stops'])
    df_each_stop_schedule['Stop_Number'] = stop
