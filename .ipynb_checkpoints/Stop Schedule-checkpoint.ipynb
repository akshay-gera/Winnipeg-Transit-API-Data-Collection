# %%
import pandas as pd
import numpy as np
import requests
import math
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import nan
from pandas.io.json import json_normalize

# %%
# Creating a list of bus stops from already extracted data. This list will be used to make api calls

df_stops = pd.read_csv('Bus_Stops.csv')
df_stops.number= df_stops.number.astype('Int64').astype('str')
stop_numbers_list = list(set(df_stops['number']))
number_of_stops = len(stop_numbers_list)
number_of_stops
# Out:
# 5085

# %% [markdown]
# # We will be using the same methodlogy of batch calling for extracting stop schedule data as well

# %%
# For 5085 bus stops we would need 5087/100 number of chunks
chunks_required = round(number_of_stops/100)

# Creating a function which will take stops list and chunks required as input
# The function with create sub-lists of 100 elements in the whole stops list of 5085 stops

def divide_chunks(stop_numbers_list,chunks_required):
    
    # Loops starts with 0 till number of stops and hops on to every another 100th element of the list
    
    for i in range(0, number_of_stops, 100):
        
        # Indexes from 100 till another 100th element
        # For example indexing at first loop i=0 is [0:100]
        # For second loop the i=100 and indexing is [100:200]
        yield stop_numbers_list[i:i + 100]

# %%
# Calling the function and giving it object name bus_stop_chunks
# Bus_stop_chunks in coverted list of chunks of list with 100 elements each

bus_stops_chunks = list(divide_chunks(stop_numbers_list, chunks_required))
print(f'Number of bus_stops chunks from original bus stops list: {len(bus_stops_chunks)}')
print(f'Number of elements in each chunk: {len(bus_stops_chunks[0])}')
# Out:
# Number of bus_stops chunks from original bus stops list: 51
# Number of elements in each chunk: 100

# %%
# Creating a function which will go inside in each bus_stop chunk list elements
# And make an api call for each bus stop

# This dataframe will capture schedule for each bus variant
df_each_stop_schedule_per_bus = pd.DataFrame()

# This data frame will populate with all bus variants schedule for each stop
df_each_stop_schedule = pd.DataFrame()

# Initializing with an empty pandas dataframe which will populate with with a chunk of 100 stops
df_stop_schedule_per_chunk = pd.DataFrame()



# This function takes in chunk_index(what chunk of the whole list to work on)
# Then for each chunk makes api calls of bus stops in that chunk

def bus_stop_schedule_chunkwise(chunk_index):
    
    # Declaring the initialized dataframe variable df_stop_schedule as a global variable
    # Without it the function will consider it to be local variable and not work
    global df_stop_schedule_per_chunk
    global df_each_stop_schedule
    global df_each_stop_schedule_per_bus
    
    # Running a for loop to make api call for each stop in the bus_stops_chunks list
    for stop in bus_stops_chunks[chunk_index]:
        if stop != None:
            try:
                response = requests.get(f"https://api.winnipegtransit.com/v3/stops/{stop}/schedule.json?api-key=wPOIZFdePaV6BdttKD7C")
                json_format = response.json()['stop-schedule']

             # Recording the information got into a temporary frame df_each_stop_schedule
                #df_each_stop_schedule = pd.DataFrame()
                #df_each_stop_schedule['name'] = 'Nothing'
                #df_each_stop_schedule['count'] = None
                #df_each_stop_schedule['Stop_Number'] = stop
                #df_each_stop_schedule.loc[len(df_each_stop_schedule.index)] = [None,None, f'{stop}']
                
                # If the search returns no errors or any empty value
                if json_format['route-schedules'] == []:
                    df_each_stop_schedule['Stop_Number'] = stop
                   
                    #print(f'Empty row added for variant {stop}')
                    
                # If the api search returns a blank search, the stop will be recorded in the dataframe with empty values
                else:
                    for i in range(len(json_format['route-schedules'])):
                        df_each_stop_schedule_per_bus = pd.json_normalize(json_format['route-schedules'][i]['scheduled-stops'])
                        df_each_stop_schedule_per_bus['Stop_Number'] = stop
                        df_each_stop_schedule = pd.concat([df_each_stop_schedule,df_each_stop_schedule_per_bus], ignore_index=True)
                    

            except:
                print(f'{stop} returned error in search. No values found for this variant')

            # Simulatenous concatanetion of each stop's info in df_stop_feature_chunk
            # This dataframe will contain records for each chunk of the big 5085 stops list
            df_stop_schedule_per_chunk = pd.concat([df_stop_schedule_per_chunk,df_each_stop_schedule], ignore_index=True)

# %%
# Initializng with index 0

chunk_index=0

# Initializing empty dataframe which will contain bus stops schedule of all bus stops
# This is our final outcome 

df_stop_schedule =pd.DataFrame()

# Creating a function to repeadtly execute above created function bus_stop_schedule_chunkwise
# On every run chunk_index increases by 1 
# We will repeadtly make calls of this function in 60 secods intervals

# This function merely runs the previous function and takes in index number of chunk list
def bus_stops_schedule(index):
    
    # Declaring chunk_index and chunks_required variable as global as its referenced before the function
    global chunk_index
    global chunks_required
    global df_stop_schedule
    global df_stop_schedule_per_chunk
    
    # The loop will run until the index_count reaches equal to chunks_required
    # which is number of bus stops in our list divided by 100 elements' chunks)
    if chunk_index <= chunks_required:
        
        # Using a for loop to call run bus_stop_schedule_chunkwise for each index position
        
        for i in [chunk_index]:
            bus_stop_schedule_chunkwise(chunk_index=chunk_index)
            
            # For each loop, index value be incremented by 1 which becomes input when function is run again
            chunk_index+=1
            
            # Concatenating with main dataframe
            df_stop_schedule = pd.concat([df_stop_schedule, df_stop_schedule_per_chunk], ignore_index=True)
        
        print(f'Chunk index {i} of Bus Stops List Added to Dataframe at {time.ctime()}')
        print(f'Number of Stops added {df_stop_schedule_per_chunk.Stop_Number.nunique()}')
        print(f'Number of rows of dataframe after addition: {len(df_stop_schedule)}' )
        
        # Emptying the last chunk's dataframe on everyloop to avoid data duplication
        df_stop_schedule_per_chunk = pd.DataFrame()
        
    else:
        print('Every stop feature put into the dataframe. Process complete')

# %%
# Importing schedule library for scheduling tasks

import schedule
import time

# Creating a schedule object which will run the bus_stops_features function at every 60 seconds intreval
# We also have defined the index to start with, i.e 0 which will initialized above
schedule.clear()
schedule.every(60).seconds.do(bus_stops_schedule, index=chunk_index)
# Out:
# Every 60 seconds do bus_stops_schedule(index=0) (last run: [never], next run: 2022-12-26 11:19:03)

# %%
# Running a while loop which will keep the scheduled job running at 1 minute intervals
# The scheduled job will run until the all chunks in the bus stops list are looped and entered into dataframe


# The loop will run until chunk_index(which is incrementing by 1 on every loop) reaches the equal to (number of chunks + 1)
# We have 41 chunks_required (sub-lists of 100 bus stops) in our whole bus stops list(of 5085 stops)
# We have incremented chunks_required+1 to enable the while loop to enter else condition when the index reaches the limit
while chunk_index <= (chunks_required-1):
    
    # If statement runs until all chunk indexes are looped, which in our case is 41
    if chunk_index <= chunks_required:
        schedule.run_pending()
    
    # Once the index reaches 49 and increments to 50, it means we have looped all the chunks 
    # And our data from 51 chunks of bus stops in the bus stop list has been entered to DataFrame df_stop_features
    else:
        # Clearing pending schedules after job is done
        schedule.clear()
        print('Scheduler Stopped. Process Complete ')
        break
# Out:
# Chunk index 0 of Bus Stops List Added to Dataframe at Mon Dec 26 11:19:16 2022
# Number of Stops added 99
# Number of rows of dataframe after addition: 15619
# Chunk index 1 of Bus Stops List Added to Dataframe at Mon Dec 26 11:20:27 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 62137
# Chunk index 2 of Bus Stops List Added to Dataframe at Mon Dec 26 11:21:39 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 147915
# Chunk index 3 of Bus Stops List Added to Dataframe at Mon Dec 26 11:22:51 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 272480
# Chunk index 4 of Bus Stops List Added to Dataframe at Mon Dec 26 11:24:04 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 433503
# Chunk index 5 of Bus Stops List Added to Dataframe at Mon Dec 26 11:25:16 2022
# Number of Stops added 110
# Number of rows of dataframe after addition: 642910
# Chunk index 6 of Bus Stops List Added to Dataframe at Mon Dec 26 11:26:30 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 892639
# Chunk index 7 of Bus Stops List Added to Dataframe at Mon Dec 26 11:27:41 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 1171590
# Chunk index 8 of Bus Stops List Added to Dataframe at Mon Dec 26 11:28:53 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 1483381
# Chunk index 9 of Bus Stops List Added to Dataframe at Mon Dec 26 11:30:06 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 1830110
# Chunk index 10 of Bus Stops List Added to Dataframe at Mon Dec 26 11:31:20 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 2212770
# Chunk index 11 of Bus Stops List Added to Dataframe at Mon Dec 26 11:32:33 2022
# Number of Stops added 105
# Number of rows of dataframe after addition: 2626969
# Chunk index 12 of Bus Stops List Added to Dataframe at Mon Dec 26 11:33:47 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 3074979
# Chunk index 13 of Bus Stops List Added to Dataframe at Mon Dec 26 11:35:00 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 3554838
# Chunk index 14 of Bus Stops List Added to Dataframe at Mon Dec 26 11:36:14 2022
# Number of Stops added 105
# Number of rows of dataframe after addition: 4068995
# Chunk index 15 of Bus Stops List Added to Dataframe at Mon Dec 26 11:37:28 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 4615962
# Chunk index 16 of Bus Stops List Added to Dataframe at Mon Dec 26 11:38:41 2022
# Number of Stops added 105
# Number of rows of dataframe after addition: 5195646
# Chunk index 17 of Bus Stops List Added to Dataframe at Mon Dec 26 11:39:55 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 5806019
# Chunk index 18 of Bus Stops List Added to Dataframe at Mon Dec 26 11:41:08 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 6449461
# Chunk index 19 of Bus Stops List Added to Dataframe at Mon Dec 26 11:42:22 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 7125564
# Chunk index 20 of Bus Stops List Added to Dataframe at Mon Dec 26 11:43:37 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 7842064
# Chunk index 21 of Bus Stops List Added to Dataframe at Mon Dec 26 11:44:51 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 8589380
# Chunk index 22 of Bus Stops List Added to Dataframe at Mon Dec 26 11:46:06 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 9367404
# Chunk index 23 of Bus Stops List Added to Dataframe at Mon Dec 26 11:47:21 2022
# Number of Stops added 107
# Number of rows of dataframe after addition: 10178233
# Chunk index 24 of Bus Stops List Added to Dataframe at Mon Dec 26 11:48:36 2022
# Number of Stops added 104
# Number of rows of dataframe after addition: 11024342
# Chunk index 25 of Bus Stops List Added to Dataframe at Mon Dec 26 11:49:50 2022
# Number of Stops added 114
# Number of rows of dataframe after addition: 11905158
# Chunk index 26 of Bus Stops List Added to Dataframe at Mon Dec 26 11:51:07 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 12823897
# Chunk index 27 of Bus Stops List Added to Dataframe at Mon Dec 26 11:52:24 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 13778260
# Chunk index 28 of Bus Stops List Added to Dataframe at Mon Dec 26 11:53:40 2022
# Number of Stops added 106
# Number of rows of dataframe after addition: 14770351
# Chunk index 29 of Bus Stops List Added to Dataframe at Mon Dec 26 11:54:55 2022
# Number of Stops added 102
# Number of rows of dataframe after addition: 15798844
# Chunk index 30 of Bus Stops List Added to Dataframe at Mon Dec 26 11:56:12 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 16858372
# <NA> returned error in search. No values found for this variant
# Chunk index 31 of Bus Stops List Added to Dataframe at Mon Dec 26 11:57:28 2022
# Number of Stops added 104
# Number of rows of dataframe after addition: 17958974
# Chunk index 32 of Bus Stops List Added to Dataframe at Mon Dec 26 11:58:51 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 19101981
# Chunk index 33 of Bus Stops List Added to Dataframe at Mon Dec 26 12:00:09 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 20279165
# Chunk index 34 of Bus Stops List Added to Dataframe at Mon Dec 26 12:01:30 2022
# Number of Stops added 103
# Number of rows of dataframe after addition: 21491884
# Chunk index 35 of Bus Stops List Added to Dataframe at Mon Dec 26 12:02:49 2022
# Number of Stops added 107
# Number of rows of dataframe after addition: 22735808
# Chunk index 36 of Bus Stops List Added to Dataframe at Mon Dec 26 12:04:06 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 24013128
# Chunk index 37 of Bus Stops List Added to Dataframe at Mon Dec 26 12:05:25 2022
# Number of Stops added 107
# Number of rows of dataframe after addition: 25324690
# Chunk index 38 of Bus Stops List Added to Dataframe at Mon Dec 26 12:06:46 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 26671206
# Chunk index 39 of Bus Stops List Added to Dataframe at Mon Dec 26 12:08:04 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 28055452
# Chunk index 40 of Bus Stops List Added to Dataframe at Mon Dec 26 12:09:25 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 29479340
# Chunk index 41 of Bus Stops List Added to Dataframe at Mon Dec 26 12:10:46 2022
# Number of Stops added 104
# Number of rows of dataframe after addition: 30935455
# Chunk index 42 of Bus Stops List Added to Dataframe at Mon Dec 26 12:12:08 2022
# Number of Stops added 106
# Number of rows of dataframe after addition: 32423233
# Chunk index 43 of Bus Stops List Added to Dataframe at Mon Dec 26 12:13:30 2022
# Number of Stops added 100
# Number of rows of dataframe after addition: 33938752
# Chunk index 44 of Bus Stops List Added to Dataframe at Mon Dec 26 12:14:51 2022
# Number of Stops added 105
# Number of rows of dataframe after addition: 35484149
# Chunk index 45 of Bus Stops List Added to Dataframe at Mon Dec 26 12:16:13 2022
# Number of Stops added 108
# Number of rows of dataframe after addition: 37064236
# Chunk index 46 of Bus Stops List Added to Dataframe at Mon Dec 26 12:17:34 2022
# Number of Stops added 105
# Number of rows of dataframe after addition: 38693114
# Chunk index 47 of Bus Stops List Added to Dataframe at Mon Dec 26 12:18:56 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 40363599
# Chunk index 48 of Bus Stops List Added to Dataframe at Mon Dec 26 12:20:19 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 42066433
# Chunk index 49 of Bus Stops List Added to Dataframe at Mon Dec 26 12:21:41 2022
# Number of Stops added 101
# Number of rows of dataframe after addition: 43808048
# Chunk index 50 of Bus Stops List Added to Dataframe at Mon Dec 26 12:23:04 2022
# Number of Stops added 85
# Number of rows of dataframe after addition: 45316247

# %%
# Dropping rows where no information on estimated arrival time is available

df_stop_schedule.dropna(subset=['times.arrival.scheduled', 'times.arrival.estimated'], inplace=True)

# %%
# Creating Delay_Time (in seconds column) which shows how much delay a bus will be 

df_stop_schedule['Delay_Time'] = (pd.to_datetime(df_stop_schedule['times.arrival.estimated']) - pd.to_datetime(df_stop_schedule['times.arrival.scheduled'])).dt.total_seconds()

# %%
df_stop_schedule['IsDelayed'] = np.where(df_stop_schedule['Delay_Time']!= 0, True, False)

# %%
df_stop_schedule
# Out:
#          Stop_Number          key cancelled times.departure.scheduled  \
# 6              30009  22722298-10     false       2022-12-26T11:59:12
# 7              30009  22722299-10     false       2022-12-26T12:44:12
# 10             30009  22722298-10     false       2022-12-26T11:59:12
# 11             30009  22722299-10     false       2022-12-26T12:44:12
# 12             40492  22722129-78     false       2022-12-26T11:20:52
# ...              ...          ...       ...                       ...
# 45316242       10061  22722436-20     false       2022-12-26T12:53:19
# 45316243       10061  22722438-18     false       2022-12-26T13:14:19
# 45316244       10061  22722434-20     false       2022-12-26T13:35:19
# 45316245       10061  22722430-18     false       2022-12-26T13:56:19
# 45316246       10061  22722428-20     false       2022-12-26T14:17:19
#
#          times.departure.estimated variant.key  \
# 6              2022-12-26T11:59:12      18-1-A
# 7              2022-12-26T12:44:12      18-1-A
# 10             2022-12-26T11:59:12      18-1-A
# 11             2022-12-26T12:44:12      18-1-A
# 12             2022-12-26T11:20:52      20-0-W
# ...                            ...         ...
# 45316242       2022-12-26T12:53:19      16-0-M
# 45316243       2022-12-26T13:14:19      16-0-B
# 45316244       2022-12-26T13:35:19      16-0-M
# 45316245       2022-12-26T13:56:19      16-0-B
# 45316246       2022-12-26T14:17:19      16-0-M
#
#                                           variant.name  bus.key bus.bike-rack  \
# 6               North Main-Corydon to Assiniboine Park    101.0         false
# 7               North Main-Corydon to Assiniboine Park    625.0         false
# 10              North Main-Corydon to Assiniboine Park    101.0         false
# 11              North Main-Corydon to Assiniboine Park    625.0         false
# 12                     Watt-Academy to Watt & Leighton    712.0         false
# ...                                                ...      ...           ...
# 45316242  Selkirk-Osborne to Tyndall Park via Manitoba    875.0         false
# 45316243   Selkirk-Osborne to Tyndall Park via Burrows    735.0         false
# 45316244  Selkirk-Osborne to Tyndall Park via Manitoba    184.0         false
# 45316245   Selkirk-Osborne to Tyndall Park via Burrows    611.0         false
# 45316246  Selkirk-Osborne to Tyndall Park via Manitoba    426.0          true
#
#          bus.wifi times.arrival.scheduled times.arrival.estimated  Delay_Time  \
# 6           false     2022-12-26T11:59:12     2022-12-26T11:59:12         0.0
# 7           false     2022-12-26T12:44:12     2022-12-26T12:44:12         0.0
# 10          false     2022-12-26T11:59:12     2022-12-26T11:59:12         0.0
# 11          false     2022-12-26T12:44:12     2022-12-26T12:44:12         0.0
# 12          false     2022-12-26T11:20:52     2022-12-26T11:20:52         0.0
# ...           ...                     ...                     ...         ...
# 45316242    false     2022-12-26T12:53:19     2022-12-26T12:53:19         0.0
# 45316243    false     2022-12-26T13:14:19     2022-12-26T13:14:19         0.0
# 45316244    false     2022-12-26T13:35:19     2022-12-26T13:35:19         0.0
# 45316245    false     2022-12-26T13:56:19     2022-12-26T13:56:19         0.0
# 45316246    false     2022-12-26T14:17:19     2022-12-26T14:17:19         0.0
#
#           IsDelayed
# 6             False
# 7             False
# 10            False
# 11            False
# 12            False
# ...             ...
# 45316242      False
# 45316243      False
# 45316244      False
# 45316245      False
# 45316246      False
#
# [44418918 rows x 14 columns]

# %%
# Since our main dataframe turns out to be 45M rows, we are randomly picing 100000 records of stop schedule data for our machine learning problem
# The intention is to save compute time due to time and hardware constraints

df_stop_schedule_sample = df_stop_schedule.sample(n=100000,  random_state=1)
df_stop_schedule_sample
# Out:
#          Stop_Number          key cancelled times.departure.scheduled  \
# 36874149       10830   22722773-2     false       2022-12-26T13:03:37
# 33432680       60776  22721899-46     false       2022-12-26T13:22:56
# 5770192        50794  22722776-49     false       2022-12-26T13:09:00
# 33425055       60776  22721004-31     false       2022-12-26T11:41:12
# 43848935       30809  22721224-29     false       2022-12-26T12:03:08
# ...              ...          ...       ...                       ...
# 11542654       30563  22722767-95     false       2022-12-26T12:19:16
# 81959          50430  22722131-78     false       2022-12-26T12:43:52
# 21374590       10022  22722774-15     false       2022-12-26T12:11:34
# 17955781       10118  22722297-73     false       2022-12-26T12:03:00
# 38913959       20311   22721822-4     false       2022-12-26T11:39:37
#
#          times.departure.estimated variant.key  \
# 36874149       2022-12-26T13:03:37      11-1-D
# 33432680       2022-12-26T13:22:56      38-1-F
# 5770192        2022-12-26T13:09:00      11-0-C
# 33425055       2022-12-26T11:41:12     650-1-S
# 43848935       2022-12-26T12:03:08      89-1-K
# ...                            ...         ...
# 11542654       2022-12-26T12:19:16      11-1-D
# 81959          2022-12-26T12:43:52      20-0-W
# 21374590       2022-12-26T12:11:34      11-0-S
# 17955781       2022-12-26T12:03:00      18-1-A
# 38913959       2022-12-26T11:39:37      44-1-L
#
#                                             variant.name  bus.key  \
# 36874149  Portage-Kildonan to North Kildonan via Donwood    191.0
# 33432680                             Salter to The Forks    419.0
# 5770192                Portage-Kildonan to Crestview via    192.0
# 33425055                     McGillivray to Seel Station    180.0
# 43848935                               to Kildonan Place    808.0
# ...                                                  ...      ...
# 11542654  Portage-Kildonan to North Kildonan via Donwood    192.0
# 81959                    Watt-Academy to Watt & Leighton    129.0
# 21374590             Portage-Kildonan to St. Charles via    300.0
# 17955781          North Main-Corydon to Assiniboine Park    345.0
# 38913959                     Grey to Broadway via London    878.0
#
#          bus.bike-rack bus.wifi times.arrival.scheduled  \
# 36874149         false    false     2022-12-26T13:03:37
# 33432680          true    false     2022-12-26T13:22:56
# 5770192          false    false     2022-12-26T13:09:00
# 33425055         false    false     2022-12-26T11:41:12
# 43848935         false    false     2022-12-26T12:03:08
# ...                ...      ...                     ...
# 11542654         false    false     2022-12-26T12:19:16
# 81959            false    false     2022-12-26T12:43:52
# 21374590         false    false     2022-12-26T12:11:34
# 17955781         false    false     2022-12-26T12:03:00
# 38913959         false    false     2022-12-26T11:39:37
#
#          times.arrival.estimated  Delay_Time  IsDelayed
# 36874149     2022-12-26T13:03:37         0.0      False
# 33432680     2022-12-26T13:22:56         0.0      False
# 5770192      2022-12-26T13:09:00         0.0      False
# 33425055     2022-12-26T11:41:12         0.0      False
# 43848935     2022-12-26T12:03:08         0.0      False
# ...                          ...         ...        ...
# 11542654     2022-12-26T12:19:16         0.0      False
# 81959        2022-12-26T12:43:52         0.0      False
# 21374590     2022-12-26T12:11:34         0.0      False
# 17955781     2022-12-26T12:03:00         0.0      False
# 38913959     2022-12-26T11:39:37         0.0      False
#
# [100000 rows x 14 columns]

# %%
df_stop_schedule_sample.IsDelayed.value_counts()
# Out:
# False    93558
# True      6442
# Name: IsDelayed, dtype: int64

# %%
df_stop_schedule_sample.to_csv('Stop_Schedule.csv', index=False)
